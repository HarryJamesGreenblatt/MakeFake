# %%
from Make_FakeCompany      import FakeCompany, fake, phony
from Make_FakeAthleticClub import FakeAthleticClub

# %%
FakeCompany()
# Out:
# Name: Lee-Mcdaniel
# Category: Professional Limited Liability Company
# Domain: Lee-Mcdaniel.org
# Number of Employees: 885
# City:  North Timothy
# State: MA
# Zip Code: 01330
# Departments: [
#    'Management',
#    'Accounting',
#    'Sales',
#    'Marketing',
#    'Security',
#    'IT',
# ]
# Employee Attributes: [
#    'Employee ID',
#    'First Name',
#    'Last Name',
#    'Email',
#    'Username',
#    'Password',
#    'Date Of Birth',
#    'SSN',
#    'Phone Number',
#    'Address',
#    'City',
#    'State',
#    'Zip Code',
#    'Hire Date',
#    'Salary',
#    'Department',
# ]
# Customer Attributes: [
#    'Customer ID',
#    'First Name',
#    'Last Name',
#    'Email',
#    'Username',
#    'Password',
#    'Phone Number',
#    'Address',
#    'City',
#    'State',
#    'Zip Code',
#    'Card Provider',
#    'Card Number',
#    'CVV',
#    'Expiration Date',
# ]
# Inventory Attributes: [
#    'Stock ID',
#     'Product',
#     'Year',
#     'Price',
# ]

# %%
FakeCompany().MakeFakeEmployees()["As_DataFrame"]
# Out:
#     Employee ID First Name  Last Name                               Email  \
# 0       8099442     Monica     Austin      monica.austin@Lee-Mcdaniel.com
# 1       5139545       Kara    Jimenez       kara.jimenez@Lee-Mcdaniel.com
# 2       7231823   Patricia   Mitchell  patricia.mitchell@Lee-Mcdaniel.com
# 3       5029864  Stephanie      Jones    stephanie.jones@Lee-Mcdaniel.com
# 4       3841923      Tracy      Kelly        tracy.kelly@Lee-Mcdaniel.com
# ..          ...        ...        ...                                 ...
# 880     7744291    Chelsey      Scott      chelsey.scott@Lee-Mcdaniel.com
# 881     5811942       Dana     Rhodes        dana.rhodes@Lee-Mcdaniel.com
# 882     7573247      Bobby    Leonard      bobby.leonard@Lee-Mcdaniel.com
# 883     6644364       Jeff      Allen         jeff.allen@Lee-Mcdaniel.com
# 884     4808891      Erica  Hernandez    erica.hernandez@Lee-Mcdaniel.com
#
#        Username    Password Date Of Birth          SSN       Phone Number  \
# 0       austinm  99KkshB5#v    08/06/1987  696-02-6630  +1-(972)-547-3248
# 1      jimenezk  $9Atk4ZEeH    01/06/1962  178-53-4838     (955) 567-0558
# 2     mitchellp  U#Hog6MkBI    05/06/1987  774-43-6048     (093) 791-8455
# 3        joness  0G1A)gzz!w    04/10/1966  430-79-7567       073-471-0827
# 4        kellyt  $)NXEq5++3    08/01/1965  536-99-9125     (112) 348-6565
# ..          ...         ...           ...          ...                ...
# 880      scottc  nk9!7IOO*#    03/15/1964  577-91-2269       693-387-3346
# 881     rhodesd  7RASwdCM$%    10/06/1971  394-01-2307       660-242-3501
# 882    leonardb  E_41TGxM$4    01/30/1976  501-69-5537  +1-(760)-057-7890
# 883      allenj  +Q5U8jB1!b    09/19/1980  882-78-4238     1-881-379-5581
# 884  hernandeze  Bc2QKkS#!_    06/16/1963  452-23-0172  +1-(080)-741-5400
#
#                              Address               City State Zip Code  \
# 0                    756 Sheila Pike             Mayton    MA    02656
# 1                   911 Wilson Crest             Oswego    MA    02775
# 2                    042 Smith Brook      North Timothy    MA    02775
# 3         26729 Jill Vista Suite 085       South Angela    MA    02100
# 4    23715 Melinda Mountain Apt. 742           Cranston    MA    02143
# ..                               ...                ...   ...      ...
# 880         552 Fox Meadows Apt. 628  East Lindseyshire    MA    01067
# 881    97066 Carter Garden Suite 518          Mishawaka    MA    02775
# 882   4861 Martinez Corner Suite 461         Austinport    MA    01635
# 883          397 Kurt Pass Suite 353      North Timothy    MA    01101
# 884             6594 Allen Stravenue         Lake Tyler    MA    02775
#
#       Hire Date     Salary  Department
# 0    09/19/2015   75174.93  Management
# 1    06/08/2014   82950.88          IT
# 2    10/25/2020   66608.78    Security
# 3    06/20/2011  106755.76          IT
# 4    12/26/2009  110219.70  Accounting
# ..          ...        ...         ...
# 880  12/02/2001   98170.71  Accounting
# 881  10/27/2005   76050.22  Accounting
# 882  03/03/2022   97798.09  Accounting
# 883  07/10/2019   97205.11  Accounting
# 884  04/21/2006   68095.77    Security
#
# [885 rows x 16 columns]

# %%
fake_customers = FakeCompany().MakeFakeCustomers()["As_DataFrame"]

# %%
fake_inventory = FakeCompany().MakeFakeInventory()["As_DataFrame"]

# %%
fake_customers
# Out:
#     Customer ID First Name Last Name                        Email   Username  \
# 0          5341      David    Santos          human2075@gmail.com    santosd
# 1          6988        Amy  Erickson       cadillac2017@yahoo.com  ericksona
# 2          1270     Daniel      Rios     tramadol1928@outlook.com      riosd
# 3          6067   Angelica    Osborn         senior1886@gmail.com    osborna
# 4          1890     Dakota     Giles            sas1909@gmail.com     gilesd
# ..          ...        ...       ...                          ...        ...
# 214        6668     Angela    Brooks      boolean1821@outlook.com    brooksa
# 215        5543     Alison    Taylor  commodities1940@outlook.com    taylora
# 216        3844    Melissa      Webb      reached1978@outlook.com      webbm
# 217        1901   Mckenzie      Bond        bracket1984@gmail.com      bondm
# 218        5682      Debra     Green            ltd1997@gmail.com     greend
#
#            Password       Phone Number                          Address  \
# 0          ZUL!BM7,     (015) 750-2837     64807 Jones Cliffs Suite 236
# 1         brianryan     1-628-678-8554              2473 Nicholas Shore
# 2          P`?UNB\t     (137) 385-9282                    912 Paul Oval
# 3    bradleypatrick       105-032-0254                9950 Billy Tunnel
# 4        cited_1970       862.382.8497     3701 Travis Summit Suite 871
# ..              ...                ...                              ...
# 214        RBiA~T'B       881-791-1147                  972 Nathan Isle
# 215        rF6SyjA9     (078) 005-9064     43713 Cabrera Trail Apt. 941
# 216        VQll++*z       043-304-1849  055 Roberts Throughway Apt. 044
# 217   spencecharles     1-939-528-1392      4760 Nathan Crest Suite 886
# 218         hcarter  +1-(955)-355-1515          04454 William Stravenue
#
#                  City State Zip Code Card Provider          Card Number  CVV  \
# 0      Lake Peterside    MA    01958         Chase    3492 064421 74515  335
# 1       North Timothy    MA    01882         Chase  5522 2712 6132 1181  746
# 2       North Timothy    MA    02786          Visa  5305 7177 0920 2378  623
# 3       North Timothy    MA    02710         Chase    3737 439096 71590  189
# 4          Hackensack    MA    02250          Visa    3762 173227 50205  512
# ..                ...   ...      ...           ...                  ...  ...
# 214  Rancho Cucamonga    MA    01054         Chase    3450 830339 29654  526
# 215     North Timothy    MA    01426         Chase  4950 5665 5590 1943  983
# 216           Warwick    MA    02499    MasterCard    3455 863441 91434  521
# 217           Rocklin    MA    02117      Discover  2505 3304 7070 0920  643
# 218     North Timothy    MA    02250         Chase    3461 919608 44660  426
#
#     Expiration Date
# 0             11/25
# 1             02/26
# 2             01/25
# 3             12/23
# 4             04/26
# ..              ...
# 214           12/25
# 215           10/27
# 216           11/22
# 217           11/27
# 218           07/26
#
# [219 rows x 15 columns]

# %%
fake_inventory
# Out:
#                    Stock ID                                    Product  Year  \
# 0    GB25FFXR00252032750835                    Intel® HD Graphics 6000  2009
# 1    GB86VATF11960065619528                         Caterpillar 329F L  2013
# 2    GB70RYKT20892146736288  Kobelco SK55SRX-6E (Multi Terrain Loader)  2012
# 3    GB31YPRH57961846992388                   Bomag CR452 (Cultivator)  2019
# 4    GB78KBRC58695570789555      Komatsu Effects Imaging (4WD Tractor)  2003
# ..                      ...                                        ...   ...
# 217  GB67VAIE69181544452584          Bobcat 435 Long Arm (2WD Tractor)  2014
# 218  GB62SFKB64482313403825                         Fiat-Hitachi FG105  2000
# 219  GB90BEMA45211441124265                           Samsung SGH-G600  2017
# 220  GB50BZJJ73968734891421     Caterpillar 545D (Hydraulic Excavator)  2006
# 221  GB81HRRA09016978196575                              Skoda Perform  2008
#
#        Price
# 0    4076.15
# 1    2459.37
# 2    4493.76
# 3    1094.65
# 4    2899.31
# ..       ...
# 217  2027.82
# 218  1573.01
# 219  4691.73
# 220  2907.01
# 221  1927.99
#
# [222 rows x 4 columns]
