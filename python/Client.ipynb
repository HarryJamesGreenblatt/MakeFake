# %%
from Make_FakeCompany   import FakeCompany

# %%
FakeCompany(employee_size=300,customer_size=196, inventory_size=112)
# Out:
# Name: Watts, Watkins and Jones
# Category: Limited Partnership
# Domain: Watts-Watkins-and-Jones.net
# # of Employees: 300
# # of Customers: 196
# # of Inventory Items: 112
# City:  Williamsbury
# State: WI
# Zip Code: 53261
# Departments: [
#    'Management',
#    'Accounting',
#    'Sales',
#    'Marketing',
#    'Security',
#    'IT',
# ]
# Employee Attributes: [
#    'Employee ID',
#    'First Name',
#    'Last Name',
#    'Email',
#    'Username',
#    'Password',
#    'Date Of Birth',
#    'SSN',
#    'Phone Number',
#    'Address',
#    'City',
#    'State',
#    'Zip Code',
#    'Hire Date',
#    'Salary',
#    'Department',
# ]
# Customer Attributes: [
#    'Customer ID',
#    'First Name',
#    'Last Name',
#    'Email',
#    'Username',
#    'Password',
#    'Phone Number',
#    'Address',
#    'City',
#    'State',
#    'Zip Code',
#    'Card Provider',
#    'Card Number',
#    'CVV',
#    'Expiration Date',
# ]
# Inventory Attributes: [
#    'Stock ID',
#     'Product',
# ...

# %%
fake_employess = FakeCompany().MakeFakeEmployees()["As_DataFrame"]

# %%
fake_employess
# Out:
#     Employee ID First Name Last Name  \
# 0       7995273       Cody   Jackson
# 1       2271559       Anna     Bowen
# 2       7156658   Cheyenne   Griffin
# 3       7253231      Jenna  Thompson
# 4       8852301    Jeffrey     Wells
# ..          ...        ...       ...
# 351     1954244      Brian     Dixon
# 352     1690142   Samantha    Wilson
# 353     8680102     Ashlee     Duran
# 354     4535977      Megan  Marshall
# 355     7227252      Sarah   Spencer
#
#                                             Email   Username    Password  \
# 0        cody.jackson@Watts-Watkins-and-Jones.org   jacksonc  ^Z+0KOht6K
# 1          anna.bowen@Watts-Watkins-and-Jones.org     bowena  iPpyjCHj_8
# 2    cheyenne.griffin@Watts-Watkins-and-Jones.org   griffinc  +57lwR4nc1
# 3      jenna.thompson@Watts-Watkins-and-Jones.org  thompsonj  2$Smi8Tsf6
# 4       jeffrey.wells@Watts-Watkins-and-Jones.org     wellsj  &B2Sfep4!4
# ...

# %%
fake_customers = FakeCompany().MakeFakeCustomers()["As_DataFrame"]

# %%
fake_customers
# Out:
#     Customer ID First Name Last Name                          Email  \
# 0          6491      Shawn  Campbell  undergraduate2040@outlook.com
# 1          4725     Andrew   Vasquez          western2086@yahoo.com
# 2          1001      Erica      Luna     institutes2089@outlook.com
# 3          5054      Vicki  Castillo            dsl1957@outlook.com
# 4          5234   Michelle     White            fully2012@yahoo.com
# ..          ...        ...       ...                            ...
# 179        2240     Shelby       May           desire2081@yahoo.com
# 180        4701       Mary     Perez           covers2043@gmail.com
# 181        6215     Nathan    Walker           merely1904@gmail.com
# 182        7010      James    Martin         porter2081@outlook.com
# 183        6279     Tracey    Morgan         easter1851@outlook.com
#
#       Username           Password       Phone Number  \
# 0    campbells        cayman_2092     1-486-662-2780
# ...

# %%
fake_inventory = FakeCompany().MakeFakeInventory()["As_DataFrame"]

# %%
fake_inventory
# Out:
#     Stock ID                           Product  Year   Price  Quantity
# 0    GB71DDE        Samsung Galaxy Grand Prime  2011  206.63         8
# 1    GB79UBS                      Fendt 6300 C  2003  290.32        47
# 2    B46AHQU                  Samsung GT-C3520  2004  536.60        26
# 3    GB74IEN                       IMT IMT 560  2012  372.49         7
# 4    78UIJK6                  Samsung Galaxy 5  2001  838.82        61
# ..       ...                               ...   ...     ...       ...
# 121  36XBMX8                  Hyundai R500LC-7  2011   86.85        54
# 122  GB88XPF                    Takeuchi TB016  2011  298.53        21
# 123  74IDTS6       Samsung Galaxy Trend 2 Lite  2005   36.43        22
# 124  GB66QKL                 Kubota KX057-4GA1  2015  736.35         0
# 125  GB80FRS  Ammann ASC110PD (Loader Backhoe)  2007   47.76        59
#
# [126 rows x 5 columns]

# %%
fake_transactions = FakeCompany().MakeFakeTransactions(fake_inventory, fake_customers)

# %%
fake_transactions
# Out:
#     Transaction ID                                       Product Sold  \
# 40   0-00-201724-5                            Intel® HD Graphics 6000
# 48   0-01-412833-0                                Samsung Galaxy Duos
# 88   0-03-905629-5                                    John Deere 850J
# 35   0-05-882048-5                                    Nokia Lumia 636
# 106  0-06-051325-X                            Intel® HD Graphics 6000
# ..             ...                                                ...
# 116  1-939427-09-6                 Caterpillar 329F L (Asphalt Paver)
# 58   1-968806-22-9             Dressta TD15M LT (Hydraulic Excavator)
# 84   1-970249-48-X  Doosan Waves Heavy (Vibratory Smooth Drum Roller)
# 3    1-9809-5935-8                                        IMT IMT 560
# 6    1-998557-37-5            Bomag Kennedy Ibm (Hydraulic Excavator)
#
#     Product ID Customer ID      Customer Name  \
# 40     B15ATAV        2811     Michael Wilson
# ...
