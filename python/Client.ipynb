# %%
from Make_FakeCompany      import FakeCompany, fake, phony
from Make_FakeAthleticClub import FakeAthleticClub

# %%
FakeAthleticClub()
# Out:
# Name: Shareware Fitness
# Category: Athletic Club
# Domain: Shareware-Fitness.net
# Number of Employees: 13
# City:  Nguyenfort
# State: VA
# Zip Code: 23169
# Departments: ['Management', 'Personal Training', 'Coaching Staff', 'Sales and Merchandise', 'Diet and Nutrition']
# Employees: odict_keys(['Employee ID', 'First Name', 'Last Name', 'Email', 'Username', 'Password', 'Date Of Birth', 'SSN', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
import pandas as pd

# %%
pd.DataFrame(
    FakeCompany().MakeFakeEmployees()
)
# Out:
#     Employee ID First Name  Last Name  \
# 0       3714020        Joe  Gutierrez
# 1       2406249      Norma     Hester
# 2       3166641    Heather      Meyer
# 3       1129133      Brian     Harris
# 4       5283527  Johnathan      Evans
# ..          ...        ...        ...
# 785     1735508      Amber      Vance
# 786     8306021    Heather    Simpson
# 787      890819    Richard    Barnett
# 788     2128385  Cassandra      Costa
# 789     1285389     Willie    Watkins
#
#                                                  Email    Username  \
# 0      joe.gutierrez@Campbell-Alexander-and-Horton.com  gutierrezj
# 1       norma.hester@Campbell-Alexander-and-Horton.com     hestern
# 2      heather.meyer@Campbell-Alexander-and-Horton.com      meyerh
# 3       brian.harris@Campbell-Alexander-and-Horton.com     harrisb
# 4    johnathan.evans@Campbell-Alexander-and-Horton.com      evansj
# ..                                                 ...         ...
# 785      amber.vance@Campbell-Alexander-and-Horton.com      vancea
# 786  heather.simpson@Campbell-Alexander-and-Horton.com    simpsonh
# 787  richard.barnett@Campbell-Alexander-and-Horton.com    barnettr
# 788  cassandra.costa@Campbell-Alexander-and-Horton.com      costac
# 789   willie.watkins@Campbell-Alexander-and-Horton.com    watkinsw
#
#        Password Date Of Birth          SSN    Phone Number  \
# 0    *oiSGkaq38    07/27/1986  380-48-2414    655-036-7012
# 1    !NMVITUTa5    06/17/1984  606-15-7301    122-872-1499
# 2    !nLCn(gLH9    03/01/1978  489-41-2182    303.038.2967
# 3    !xl#ydI4I9    02/09/1984  114-79-8682  (934) 185-0685
# 4    !zPjD!hL06    11/15/1992  178-78-4052  (106) 060-9889
# ..          ...           ...          ...             ...
# 785  %X2j_lXa^i    02/21/1967  223-96-6232  1-401-455-4579
# 786  *SwD!Hwb%8    03/30/1977  309-31-0015    284.332.6232
# 787  7%OgJCbe*V    11/01/1990  577-97-3571    667-870-9852
# 788  %j87Qsfb$G    10/01/1968  416-28-3987  1-462-119-6567
# 789  TPr3CjlGY#    11/22/1981  039-44-2477  (275) 933-9640
#
#                                Address              City State Zip Code  \
# 0                 5362 Robert Causeway         Karentown    DC    20036
# 1         3752 Greene Parkway Apt. 603      Anitaborough    DC    20017
# 2                   24555 Wilson Locks      Anitaborough    DC    20036
# 3                    3110 Dillon Ports      Anitaborough    DC    20012
# 4                  737 Charles Islands        Marysville    DC    20019
# ..                                 ...               ...   ...      ...
# 785            335 Ryan Shore Apt. 116       Elaineshire    DC    20030
# 786        614 Jennifer Views Apt. 079  North Lauderdale    DC    20036
# 787                 500 Zachary Square       Port Evelyn    DC    20039
# 788  04840 Antonio Underpass Suite 882   College Station    DC    20001
# 789               98546 Jamie Junction      Anitaborough    DC    20039
#
#       Hire Date    Salary  Department
# 0    10/16/2014  71143.88  Accounting
# 1    08/23/2022  82863.00    Security
# 2    03/13/2006  78922.86    Security
# 3    05/21/2009  89492.02   Marketing
# 4    09/11/2002  64627.77  Management
# ..          ...       ...         ...
# 785  01/30/2000  96566.04   Marketing
# 786  09/27/2019  55082.47   Marketing
# 787  06/20/2018  77515.43       Sales
# 788  06/10/2018  54661.61          IT
# 789  09/03/2000  58028.38  Accounting
#
# [790 rows x 16 columns]

# %%
pd.DataFrame(
    FakeCompany().MakeFakeCustomers()
)
# Out:
#     Customer ID   First Name Last Name                     Email   Username  \
# 0          2917        David   Sanders     swing1853@outlook.com   sandersd
# 1          9818       Steven    Decker       lloyd1974@yahoo.com    deckers
# 2          3059      Kathryn    Graham      void1883@outlook.com    grahamk
# 3          5290      Natalie      Cole     remains1835@yahoo.com      colen
# 4          2453         Anna     Cross     editors1982@yahoo.com     crossa
# ..          ...          ...       ...                       ...        ...
# 360        7721       Justin    Berger    aluminum1874@gmail.com    bergerj
# 361        3586  Christopher  Williams   afternoon1944@yahoo.com  williamsc
# 362        1816      Melissa  Gonzales     friends2071@gmail.com  gonzalesm
# 363        2064       Brandy   Jackson  forecast2026@outlook.com   jacksonb
# 364        7848        Brian     Cross   composite1832@yahoo.com     crossb
#
#             Password       Phone Number                      Address  \
# 0      actively_1800       908.749.9741             0329 Turner Keys
# 1           msanchez       045.415.6593  9533 Isaiah Walks Suite 011
# 2           0B*m"q`:       335.527.4308  7452 Knight Garden Apt. 781
# 3    influences_1868     (030) 902-4054         8317 Catherine Place
# 4    catherinenewman       624-021-1806         0991 Patricia Bypass
# ..               ...                ...                          ...
# 360       jeremiah25  +1-(355)-643-9298         16130 James Parkways
# 361           rsmith     (112) 390-7126           48207 Smith Street
# 362       maine_2008     1-556-651-7151           4643 Angela Plains
# 363     filling_1959  +1-(366)-701-9613  3681 Charles Glen Suite 864
# 364  paperbacks_1883  +1-(474)-561-0915            106 Nicole Island
#
#                   City State Zip Code Card Provider          Card Number  CVV  \
# 0         Anitaborough    DC    20020         Chase  4633 3794 8649 4268  528
# 1        Coconut Creek    DC    20014         Chase  2507 7481 5688 5939  172
# 2         Anitaborough    DC    20039    MasterCard  4815 3251 3885 0027  725
# 3            New Kevin    DC    20035    MasterCard  4067 4256 3852 0446  128
# 4           Thomasport    DC    20020    MasterCard  2477 6809 4362 4204  833
# ..                 ...   ...      ...           ...                  ...  ...
# 360   South Burlington    DC    20034      Discover  4840 8718 8793 2713  930
# 361         East Tracy    DC    20006          Visa  4023 4328 6779 2665  505
# 362    New Michaelland    DC    20009      Discover  2458 3424 6123 6845  951
# 363           Stockton    DC    20022    MasterCard    3494 282230 17925  041
# 364  South Jeffreyfort    DC    20014          Visa    3483 179284 50773  564
#
#     Expiration Date
# 0             06/26
# 1             10/23
# 2             05/23
# 3             02/28
# 4             10/24
# ..              ...
# 360           04/28
# 361           06/28
# 362           07/28
# 363           05/23
# 364           07/24
#
# [365 rows x 15 columns]

# %%
pd.DataFrame(
    FakeCompany().MakeFakeInventory()
)
# Out:
#                Stock Number           Make           Model  \
# 0    GB73QJFO96992199544801        Case IH         9105 MT
# 1    GB22XVXS66343836371378         Valmet            644E
# 2    GB48CWTD80549757194293     John Deere            612H
# 3    GB28SILX33618576472889         Kubota           2234W
# 4    GB47NEDV02925789561178     John Deere         CC1300C
# ..                      ...            ...             ...
# 560  GB57IJLI03037778763531    Caterpillar  Variant 380 RC
# 561  GB60SJQT80852066754271        Hitachi            CT47
# 562  GB29ACMO63594476760681  International            322D
# 563  GB96CYEV45715276367220         Kubota       PC220LC-8
# 564  GB81PHCX48028444865633    New Holland            G67G
#
#                       Category  Year
# 0                  4WD Tractor  2007
# 1    Static Smooth Drum Roller  2005
# 2               Midi Excavator  2006
# 3            Skid Steer Loader  2010
# 4              Crawler Tractor  2007
# ..                         ...   ...
# 560          Skid Steer Loader  2002
# 561                      Baler  2014
# 562        Hydraulic Excavator  2011
# 563             Mini Excavator  2009
# 564               Motor Grader  2009
#
# [565 rows x 5 columns]
