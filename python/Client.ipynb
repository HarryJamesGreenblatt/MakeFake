# %%
from Make_FakeCompany      import FakeCompany, fake, phony
from Make_FakeAthleticClub import FakeAthleticClub

# %%
FakeAthleticClub()
# Out:
# Name: Immigration Fitness
# Category: Athletic Club
# Domain: Immigration-Fitness.org
# Number of Employees: 85
# City:  Valerieland
# State: WI
# Zip Code: 54593
# Departments: ['Management', 'Personal Training', 'Coaching Staff', 'Sales and Merchandise', 'Diet and Nutrition']
# Employees: odict_keys(['Employee ID', 'First Name', 'Last Name', 'Email', 'Username', 'Password', 'Date Of Birth', 'SSN', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
import pandas as pd

# %%
pd.DataFrame(
    FakeCompany().MakeFakeEmployees()
)
# Out:
#     Employee ID First Name Last Name                           Email  \
# 0       6715166    Timothy     Scott    timothy.scott@Kelley-PLC.com
# 1       1522976     Taylor  Griffith  taylor.griffith@Kelley-PLC.com
# 2       8334435     Jordan     Perry     jordan.perry@Kelley-PLC.com
# 3       3439383    Valerie   Meadows  valerie.meadows@Kelley-PLC.com
# 4       2986225       John    Taylor      john.taylor@Kelley-PLC.com
# ..          ...        ...       ...                             ...
# 212     6013807      Wendy     Drake      wendy.drake@Kelley-PLC.com
# 213     8844187   Patricia    Pierce  patricia.pierce@Kelley-PLC.com
# 214     7244404     Manuel     Moore     manuel.moore@Kelley-PLC.com
# 215     3076233      Julie     Scott      julie.scott@Kelley-PLC.com
# 216     1530648       Mary  Johnston    mary.johnston@Kelley-PLC.com
#
#       Username    Password Date Of Birth          SSN    Phone Number  \
# 0       scottt  4(x1v_xy7O    02/09/1979  605-10-1920    840.688.4034
# 1    griffitht  &&S5PJo5%^    03/14/1976  043-28-7827    919-330-9556
# 2       perryj  #8!t8Cnvu^    12/25/1983  529-39-9737    009.196.2548
# 3     meadowsv  n$69RwB&tL    06/09/1960  032-81-6947    105.882.0506
# 4      taylorj  ZL8Pgo%dw^    12/22/1979  119-52-4259  1-732-075-2713
# ..         ...         ...           ...          ...             ...
# 212     drakew  q7D*d%*%(q    12/17/1991  424-02-2356  (466) 870-1410
# 213    piercep  af&F8Pu(Io    11/30/1959  539-84-5880  (608) 716-6491
# 214     moorem  1I*RqouB+4    01/15/1982  746-36-3109    810.724.7885
# 215     scottj  JX1*AYw$X)    02/20/1972  102-10-2036  (083) 964-5414
# 216  johnstonm  $u469PRvP&    02/05/1994  050-84-5161    609.663.1988
#
#                           Address             City State Zip Code   Hire Date  \
# 0       661 Thomas Court Apt. 968      Noblesville    HI    96718  11/09/2022
# 1    91717 Campos Rapid Suite 278   Hendersonmouth    HI    96719  11/24/2022
# 2             28670 Hoover Shores        Englewood    HI    96811  09/29/2008
# 3    55108 Bond Harbors Suite 042  Lake Rickymouth    HI    96856  07/30/2000
# 4             2761 English Courts   Hendersonmouth    HI    96763  08/01/2016
# ..                            ...              ...   ...      ...         ...
# 212            14178 Johnson Road       Long Beach    HI    96833  09/15/2008
# 213            025 Clements Knoll    Josephchester    HI    96793  03/27/2016
# 214              839 King Prairie           Bartow    HI    96841  05/07/2017
# 215               6167 Boyd Curve   Hendersonmouth    HI    96763  01/17/2000
# 216         71897 Brianna Circles        Masonstad    HI    96715  11/29/2015
#
#         Salary  Department
# 0    101017.35    Security
# 1     88103.99          IT
# 2     51122.42       Sales
# 3     86561.82  Management
# 4    105277.22    Security
# ..         ...         ...
# 212  103087.63   Marketing
# 213   58234.22       Sales
# 214  121667.66       Sales
# 215  111244.53  Accounting
# 216  119846.74  Management
#
# [217 rows x 16 columns]

# %%
pd.DataFrame(
    FakeCompany().MakeFakeCustomers()
)
# Out:
#     Customer ID First Name   Last Name                     Email     Username  \
# 0          3057      Alice       Meyer       ice1821@outlook.com       meyera
# 1          6202     Travis    Mcintyre      design1905@gmail.com    mcintyret
# 2          1030    Raymond     Johnson      carlos2021@gmail.com     johnsonr
# 3          2639  Elizabeth   Hernandez      dave1836@outlook.com   hernandeze
# 4          1064       Ryan  Montgomery     solve2055@outlook.com  montgomeryr
# ..          ...        ...         ...                       ...          ...
# 428        5319    Gregory     Skinner       about1955@yahoo.com     skinnerg
# 429        6009       Adam    Gonzales  protection1827@yahoo.com    gonzalesa
# 430        5897    Michael       Ramos     modes2056@outlook.com       ramosm
# 431        8219    Melissa     Johnson  indicating1844@gmail.com     johnsonm
# 432        4410    Chelsea       Weeks         hip2091@yahoo.com       weeksc
#
#           Password       Phone Number                      Address  \
# 0          diane35  +1-(203)-403-8654            922 Wilson Corner
# 1    martinezbrian     1-123-069-0764      357 Carrillo Trafficway
# 2         >o0LgH+~  +1-(043)-565-3822              477 Sloan Point
# 3     surveys_1897     (730) 970-5910  41134 Wright Coves Apt. 290
# 4        william72       051.580.3257           749 Victoria Curve
# ..             ...                ...                          ...
# 428    listen_1912       591.902.7857              827 Pierce Fort
# 429       G/lgBPk-       039.264.2916        96099 Melanie Mission
# 430  november_1862       687-642-6992       659 Kelly Dam Apt. 328
# 431       -)+E2%Af     (126) 619-4231     4653 Smith Spur Apt. 796
# 432     blast_1898     1-085-473-6345    464 Tracy Bypass Apt. 848
#
#                 City State Zip Code     Card Provider          Card Number  \
# 0    Cunninghammouth    HI    96883  American Express    3418 032011 36293
# 1     New Terrymouth    HI    96893             Chase  2413 9764 3413 6741
# 2         Turnerbury    HI    96872        MasterCard  4682 0429 3182 5888
# 3     Lake Kevinfort    HI    96893              Visa  5544 8958 9662 6632
# 4     Hendersonmouth    HI    96893  American Express    3774 533788 66145
# ..               ...   ...      ...               ...                  ...
# 428   Hendersonmouth    HI    96803              Visa  4219 7773 9115 2115
# 429   Hendersonmouth    HI    96781          Discover  2310 5112 7119 7540
# 430   Hendersonmouth    HI    96765        MasterCard    3454 336780 91536
# 431   West Lafayette    HI    96746          Discover  2394 9066 0781 1443
# 432           Oxnard    HI    96882             Chase    3755 757868 19340
#
#      CVV Expiration Date
# 0    847           11/26
# 1    824           12/28
# 2    861           06/22
# 3    796           02/26
# 4    286           11/22
# ..   ...             ...
# 428  694           03/27
# 429  358           05/23
# 430  085           01/26
# 431  585           03/28
# 432  033           03/25
#
# [433 rows x 15 columns]
