# %%
from Make_FakeCompany      import FakeCompany
from Make_FakeAthleticClub import FakeAthleticClub
from Make_FakeMusicStore   import FakeMusicStore

# %%
FakeCompany()
# Out:
# Name: Adams, Johnson and Golden
# Category: Professional Limited Liability Company
# Number of Employees: 448
# City:  South Tammie
# State: CA
# Zip Code: 94163
# Departments: ['Management', 'Accounting', 'Sales', 'Marketing', 'Security', 'IT']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
FakeAthleticClub()
# Out:
# Name: Boobs Fitness
# Category: Athletic Club
# Number of Employees: 142
# City:  Derekland
# State: MO
# Zip Code: 65802
# Departments: ['Management', 'Personal Training', 'Coaching Staff', 'Sales and Merchandise', 'Diet and Nutrition']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
FakeMusicStore()
# Out:
# Name: Operators Unlimited Music
# Category: Music Store
# Number of Employees: 21
# City:  Lisaville
# State: MO
# Zip Code: 64230
# Departments: ['Management', 'Record Sales', 'Instrument Sales', 'Instrument Repair and Maintenance', 'Teaching Staff', 'Marketing']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
import pandas as pd

# %%
pd.DataFrame(
    FakeAthleticClub().MakeFakePayroll()
)
# Out:
#     Employee ID First Name Last Name Date Of Birth       Phone Number  \
# 0         70498    Jessica    Arnold    04/07/1995     (216) 833-9475
# 1         10614    Richard    Clarke    10/25/1986     1-413-136-9718
# 2         24466    Gregory  Phillips    09/29/1992  +1-(256)-883-3164
# 3         34715     Robert   Nichols    02/13/1999     (335) 087-6219
# 4         60529    Anthony  Martinez    07/31/1996       974.015.3991
# ..          ...        ...       ...           ...                ...
# 137       76149    Michael   Stewart    09/27/1998       634.623.3402
# 138       10382      April      Hart    04/26/1992     (258) 512-0228
# 139       88745        Amy      Hill    04/26/2000     (512) 485-9743
# 140       30528    Rebecca    Harris    01/22/1995       406.401.1090
# 141       28867      Diana   Jimenez    10/11/1996     1-242-660-3687
#
#                           Address               City State Zip Code  \
# ...

# %%
pd.DataFrame(
    FakeAthleticClub().MakeFakeMembers()
)
# Out:
#     First Name  Last Name    Phone Number                        Address  \
# 0       Edward      Petty    171.919.5103      39415 Thomas Dam Apt. 574
# 1         Adam     Massey    730-348-5739               807 Mccoy Spring
# 2       Robert     Taylor  (178) 722-0996              82190 Lewis Inlet
# 3       Ronald   Williams  (962) 849-8387    67522 Tyler Circle Apt. 646
# 4         Anne    Salazar    870-825-8450      3624 Ramos Drive Apt. 848
# ..         ...        ...             ...                            ...
# 203      Henry     Taylor  (374) 267-4213  13928 Bullock Roads Suite 953
# 204      Jesse  Blackburn  1-475-235-0454    07977 Richard Keys Apt. 432
# 205      April    Goodwin  (203) 650-6418          6668 Christopher Flat
# 206       Lisa     Meyers  1-682-351-6794   039 Scott Junction Suite 262
# 207     Ashley      Baker  (671) 204-7952      924 Brenda Loaf Suite 670
#
#                  City State Zip Code Member ID Membership Date Membership Plan
# ...
