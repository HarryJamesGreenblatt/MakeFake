# %%
from Make_FakeCompany      import FakeCompany, fake, phony
from Make_FakeAthleticClub import FakeAthleticClub

# %%
FakeCompany()
# Out:
# Name: Jones-Logan
# Category: Corporation
# Domain: Jones-Logan.net
# # of Employees: 800
# # of Customers: 78
# # of Inventory Items: 248
# City:  Port Samantha
# State: VA
# Zip Code: 22787
# Departments: [
#    'Management',
#    'Accounting',
#    'Sales',
#    'Marketing',
#    'Security',
#    'IT',
# ]
# Employee Attributes: [
#    'Employee ID',
#    'First Name',
#    'Last Name',
#    'Email',
#    'Username',
#    'Password',
#    'Date Of Birth',
#    'SSN',
#    'Phone Number',
#    'Address',
#    'City',
#    'State',
#    'Zip Code',
#    'Hire Date',
#    'Salary',
#    'Department',
# ]
# Customer Attributes: [
#    'Customer ID',
#    'First Name',
#    'Last Name',
#    'Email',
#    'Username',
#    'Password',
#    'Phone Number',
#    'Address',
#    'City',
#    'State',
#    'Zip Code',
#    'Card Provider',
#    'Card Number',
#    'CVV',
#    'Expiration Date',
# ]
# Inventory Attributes: [
#    'Stock ID',
#     'Product',
#     'Year',
#     'Price',
#     'Quantity',
# ]

# %%
fake_customers = FakeCompany().MakeFakeCustomers()["As_DataFrame"]

# %%
fake_customers
# Out:
#    Customer ID First Name Last Name                         Email  Username  \
# 0         1737     Samuel     Lopez  subsidiaries1815@outlook.com    lopezs
# 1         7933    Michael    Taylor          lose1861@outlook.com   taylorm
# 2         1902    Stanley      Dunn  cancellation2093@outlook.com     dunns
# 3         6576        Sue     Clark          neil2071@outlook.com    clarks
# 4         7162  Elizabeth     Moore           laugh1993@yahoo.com    mooree
# ..         ...        ...       ...                           ...       ...
# 73        6140       Cole    Kelley        blocking1862@gmail.com   kelleyc
# 74        3881   Danielle   Collins             ben2044@gmail.com  collinsd
# 75        1979      David    Porter          lime1935@outlook.com   porterd
# 76        7324    Douglas      Hahn          abroad1967@gmail.com     hahnd
# 77        3456      Gavin    Thomas        plymouth1916@yahoo.com   thomasg
#
#        Password       Phone Number                       Address  \
# 0      7&ti@.8m       523-193-1712            8762 Leonard Fords
# 1    games_2020       910-625-7289     3952 Owens Camp Suite 544
# 2     card_2001     1-058-033-0127             925 Jessica Hills
# 3      xN9B<^ey       376.853.7399            68387 Michael Road
# 4   baileykevin  +1-(501)-361-3481             54397 Brooke Mews
# ..          ...                ...                           ...
# 73     TasKp."7     1-844-546-4582             821 Sabrina Crest
# 74      oramsey     1-527-744-5735              1193 Alice Mount
# 75  davidrogers     1-523-434-5233  19873 Devin Knolls Suite 972
# 76     ,H*1MmHP       646-553-2560      309 Smith Coves Apt. 716
# 77     rhonda82     (778) 657-8106   482 Grant Mountain Apt. 575
#
#                 City State Zip Code     Card Provider          Card Number  \
# 0           Kirkland    VA    22712        MasterCard    3752 582898 69936
# 1         Port Keith    VA    24285              Visa    3702 871337 92437
# 2        Foster City    VA    22562              Visa  5516 4814 2726 0110
# 3      Port Samantha    VA    23163              Visa  4302 9262 8328 5313
# 4       Olive Branch    VA    22849          Discover  4745 2070 2881 8048
# ..               ...   ...      ...               ...                  ...
# 73  Christopherburgh    VA    23395  American Express  2575 7140 1905 4425
# 74   Lake Rachelbury    VA    24527          Discover  4771 1948 9106 1368
# 75       New Jessica    VA    23395             Chase  4834 2019 4594 8048
# 76       Hillchester    VA    22426          Discover    3477 125569 36526
# 77        Des Moines    VA    24587              Visa  4898 6732 0127 7945
#
#     CVV Expiration Date
# 0   331           10/25
# 1   533           05/25
# 2   168           05/24
# 3   682           05/24
# 4   674           10/26
# ..  ...             ...
# 73  402           01/27
# 74  913           08/27
# 75  203           08/28
# 76  402           06/23
# 77  050           12/26
#
# [78 rows x 15 columns]

# %%
fake_inventory = FakeCompany().MakeFakeInventory()["As_DataFrame"]

# %%
fake_inventory
# Out:
#                    Stock ID  \
# 0    GB62KBVE81469286965584
# 1    GB57TPME10566450706304
# 2    GB85WFGD28875049844445
# 3    GB07ZLCR84898685757791
# 4    GB83IRVE86932821982476
# ..                      ...
# 243  GB17EOFA54334189982616
# 244  GB48QPNK88945704996747
# 245  GB07QWYW26363000148823
# 246  GB65IIHC42667493042595
# 247  GB79ICKD85174993073820
#
#                                                Product  Year    Price  \
# 0                                 Apple iPhone 6s Plus  2013  4508.15
# 1                              NVIDIA GeForce GTX 1070  2018  4365.58
# 2                                      Nokia Lumia 625  2011  4787.39
# 3                                           Saab Slide  2003  2392.60
# 4    John Deere 9670 STS (Vibratory Smooth Drum Rol...  2012   310.22
# ..                                                 ...   ...      ...
# 243                    John Deere 8320RT (4WD Tractor)  2000  2923.50
# 244                               Samsung Galaxy Young  2013   885.69
# 245              John Deere 953J (Hydraulic Excavator)  2010  4534.45
# 246                              Samsung Galaxy Note 7  2019  4426.45
# 247          Caterpillar Anniversary Respond (Skidder)  2011  4564.43
#
#      Quantity
# 0          42
# 1          58
# 2          21
# 3          40
# 4           4
# ..        ...
# 243        41
# 244         7
# 245        50
# 246         9
# 247        63
#
# [248 rows x 5 columns]

# %%
import pandas

larger_size = (

    len(fake_inventory)  
    if  len(fake_inventory) > len(fake_customers)

    else                     
        len(fake_customers)

)

base = pandas.concat(
    [

        pandas.Series(
            [
                fake.isbn10()
                for _ in range(larger_size)
            ], 
            name='Transaction ID'
        ),

        fake_inventory['Product'],
        fake_customers['Customer ID'],

        fake_customers['First Name']
        +
        ' '
        +
        fake_customers['Last Name'],

        fake_customers['Address']
        +
        ', '
        +
        fake_customers['City']
        +
        ', '
        +
        fake_customers['State']
        +
        ' '
        +
        fake_customers['Zip Code'],

        fake_customers['Card Number'],
        fake_customers['Card Provider'],
        fake_inventory['Price'],

        pandas.Series(
            [
                phony.Datetime().date(                   # fake data method for
                    2020,                                # a providing random 
                    2022                                 # dates between a 
                ).strftime('%m/%d/%Y')

                for _ in range(larger_size)
            ], 
            name='Payment Date'
        ),

    ],

    axis=1  

).dropna().rename( 
    columns={
        'Price':'Payment',
        'Product':'Product Sold',
        0:'Customer Name',
        1:'Customer Address'
    } 
).sort_values("Transaction ID")

# %%
base
# Out:
#    Transaction ID                                    Product Sold Customer ID  \
# 39  0-03-716400-7                 Caterpillar AP200 (2WD Tractor)        7946
# 36  0-08-842280-1                        Samsung Galaxy Note Edge        2016
# 37  0-10-188056-1                               Skoda Necessarily        3599
# 20  0-10-831143-0                                 Infiniti Helped        3417
# 51  0-15-003812-7                               New Holland TL90A        6663
# ..            ...                                             ...         ...
# 56  1-903490-85-5                         Intel® HD Graphics 5500        4463
# 10  1-927765-71-4                         NVIDIA GeForce GTX 1080        5145
# 59  1-931294-91-7  New Holland Trailers Holding (Crawler Tractor)        2786
# 24  1-964952-79-4               JCB Gas Pan (Hydraulic Excavator)        4267
# 45  1-992812-35-7                      AMCO Repair Lamps (Harrow)        8325
#
#          Customer Name                                   Customer Address  \
# 39   Christopher Brown   11755 Dylan Stravenue, East Russellton, VA 22366
# 36        Dawn Jimenez  0873 Amanda Fords Suite 630, New Smyrna Beach,...
# 37       Susan Collins  80454 Hurley Branch Suite 498, Port Michaeltow...
# 20    Katelyn Johnston       816 Miller Dam Apt. 065, Juliafurt, VA 23742
# 51       Timothy Huang  95573 Andrew Plaza Apt. 468, Port Samantha, VA...
# ..                 ...                                                ...
# 56      Tiffany Ortega       10503 Dean Plaza, East Janiceville, VA 23395
# 10  Jennifer Whitehead       303 Rodriguez Islands, West Thomas, VA 24594
# 59       Julie Johnson  678 Goodman Landing Apt. 470, Port Samantha, V...
# 24      Sarah Lawrence             69900 Baird Road, New Angela, VA 22055
# 45           Summer Wu       942 Flowers Circles, Port Samantha, VA 22905
#
#             Card Number     Card Provider  Payment Payment Date
# 39    3401 093238 62662          Discover  2394.60   07/08/2021
# 36  4422 1906 5211 9315              Visa  4190.46   04/01/2022
# 37    3472 511834 39083        MasterCard  1348.95   10/02/2021
# 20  5127 1376 4576 5105              Visa  4902.61   08/21/2020
# 51    3482 815979 07234        MasterCard  1200.39   04/17/2021
# ..                  ...               ...      ...          ...
# 56  4460 4439 6105 0686             Chase  2447.43   07/23/2022
# 10    3722 997743 18727              Visa  2734.77   05/17/2020
# 59  4950 0599 5321 3566  American Express  4320.02   08/23/2022
# 24  5187 6143 9075 6437          Discover  3884.53   01/03/2022
# 45  2359 6746 0119 7465        MasterCard   127.20   03/26/2022
#
# [78 rows x 9 columns]
