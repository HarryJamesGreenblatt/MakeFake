# %%
from Make_FakeCompany      import FakeCompany, fake, phony
from Make_FakeAthleticClub import FakeAthleticClub

# %%
FakeAthleticClub()
# Out:
# Name: Accounting Fitness
# Category: Athletic Club
# Domain: Accounting-Fitness.com
# Number of Employees: 135
# City:  North Markborough
# State: MI
# Zip Code: 48812
# Departments: ['Management', 'Personal Training', 'Coaching Staff', 'Sales and Merchandise', 'Diet and Nutrition']
# Employees: odict_keys(['Employee ID', 'First Name', 'Last Name', 'Email', 'Username', 'Password', 'Date Of Birth', 'SSN', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
import pandas as pd

# %%
pd.DataFrame(
    FakeCompany().MakeFakeEmployees()
)
# Out:
#     Employee ID First Name Last Name  \
# 0       7017167      Bryan     Smith
# 1       2021476  Stephanie   Salazar
# 2       1582568       Rose     Davis
# 3        638379      Cathy     Brown
# 4       6293692   Kimberly    Martin
# ..          ...        ...       ...
# 117     6185017    Suzanne  Ferguson
# 118     7056028  Cassandra     Young
# 119     5895937     Olivia    Barker
# 120     8341503      Wayne     Bates
# 121     6519255  Elizabeth     Boone
#
#                                                Email   Username    Password  \
# 0          bryan.smith@Macdonald-Huynh-and-Jones.com     smithb  nTI+t^sR&2
# 1    stephanie.salazar@Macdonald-Huynh-and-Jones.com   salazars  Fnz^0Vqf!)
# 2           rose.davis@Macdonald-Huynh-and-Jones.com     davisr  ^&sRUn2td1
# 3          cathy.brown@Macdonald-Huynh-and-Jones.com     brownc  ##@4AojAyW
# 4      kimberly.martin@Macdonald-Huynh-and-Jones.com    martink  @Xo9POrbo*
# ..                                               ...        ...         ...
# 117   suzanne.ferguson@Macdonald-Huynh-and-Jones.com  fergusons  B6QYm3QG@v
# 118    cassandra.young@Macdonald-Huynh-and-Jones.com     youngc  1s#Hw#Wb&2
# 119      olivia.barker@Macdonald-Huynh-and-Jones.com    barkero  7X0TSJjv!4
# 120        wayne.bates@Macdonald-Huynh-and-Jones.com     batesw  (zoJKTR*0^
# 121    elizabeth.boone@Macdonald-Huynh-and-Jones.com     boonee  $DKh6Fccn&
#
#     Date Of Birth          SSN       Phone Number  \
# 0      11/12/1962  567-47-6988     (139) 009-4246
# 1      02/11/1974  618-97-9497       310.911.9670
# 2      08/07/1962  257-29-0035  +1-(561)-979-6071
# 3      07/28/1995  221-59-5215       714.878.6208
# 4      04/18/1990  488-70-5697       129.023.5760
# ..            ...          ...                ...
# 117    05/22/1993  837-22-6951       054.222.2556
# 118    10/12/1963  152-49-4042     1-640-189-9722
# 119    03/21/1990  253-50-4278  +1-(998)-695-0580
# 120    10/23/1993  832-96-6909     1-284-810-4923
# 121    12/12/1960  318-92-5172       178-806-0953
#
#                           Address                City State Zip Code  \
# 0     552 Samantha Oval Suite 812  Lake Katherinetown    AK    99664
# 1                 3929 Anne Brook         Brandonport    AK    99931
# 2             6604 Sherry Mission           Lynchburg    AK    99931
# 3        511 Summers Key Apt. 637         Brandonport    AK    99758
# 4               31539 Bryce Hills             Phoenix    AK    99816
# ..                            ...                 ...   ...      ...
# 117             286 Nelson Manors              Warren    AK    99810
# 118        819 Christopher Shoals           Port Omar    AK    99604
# 119   5877 Jason Hollow Suite 483         Brandonport    AK    99921
# 120  4918 Sherry Orchard Apt. 429         Brandonport    AK    99610
# 121            9475 Robert Bridge         Brandonport    AK    99607
#
#       Hire Date     Salary  Department
# 0    12/08/2016   53714.11  Management
# 1    05/25/2014   66681.14    Security
# 2    02/15/2019   68106.70  Management
# 3    02/02/2003   68442.36    Security
# 4    09/24/2014  120485.24    Security
# ..          ...        ...         ...
# 117  07/26/2017   82635.96       Sales
# 118  06/17/2022   50217.49       Sales
# 119  09/23/2019   76840.28   Marketing
# 120  08/28/2015   52524.11  Management
# 121  04/03/2019  103654.54    Security
#
# [122 rows x 16 columns]

# %%
pd.DataFrame(
    FakeCompany().MakeFakeCustomers()
)
# Out:
#     Customer ID   First Name Last Name                      Email  Username  \
# 0          2658    Christina      Neal  henderson2078@outlook.com     nealc
# 1          1851        Kevin    Keller        audio1908@gmail.com   kellerk
# 2          3074  Christopher   Schmidt   dependence2018@gmail.com  schmidtc
# 3          6076        Danny    Nelson  significant1986@yahoo.com   nelsond
# 4          7053        Linda    Miller       cruz1900@outlook.com   millerl
# ..          ...          ...       ...                        ...       ...
# 290        3909       Andrea     Petty        every1881@gmail.com    pettya
# 291        3038       Briana      Reed   district2018@outlook.com     reedb
# 292        4273       Joshua   Vazquez     scanning1861@gmail.com  vazquezj
# 293        8537       Connie   Johnson     darkness2064@gmail.com  johnsonc
# 294        8146        Scott      Hall        dense1986@gmail.com     halls
#
#        Password    Phone Number                          Address  \
# 0    %8#uQOd!ZY  (817) 410-6902   80765 Virginia Plain Suite 024
# 1    &RL6wPb101    803-121-4133  25811 Roberts Junction Apt. 332
# 2    FFC2%3gjq)  1-803-083-3317      47807 John Summit Suite 451
# 3    %p_Wncm6u8  1-726-537-7047   40060 Kristine Drives Apt. 051
# 4    M3s^Dvgt$T  1-715-635-5493                173 John Mountain
# ..          ...             ...                              ...
# 290  @nn0WRiV8+    828-460-8287                  221 Susan Field
# 291  Se2MHqJvg&    817-757-8764                  116 Davis Alley
# 292  #8cVsslA0v    523-270-5248       541 Lance Orchard Apt. 480
# 293  W91Tu(GfQ&  (863) 918-8775         02552 Gutierrez Motorway
# 294  ZrF4GJ%q_9    741.593.3410                 1281 Joshua Ford
#
#                         City State Zip Code Credit Card Provider  \
# 0               Blue Springs    AK    99514     American Express
# 1                     Merced    AK    99692                 Visa
# 2                Thomasville    AK    99839                 Visa
# 3                Brandonport    AK    99635             Discover
# 4                Brandonport    AK    99551     American Express
# ..                       ...   ...      ...                  ...
# 290          West Aprilshire    AK    99523             Discover
# 291              Brandonport    AK    99514     American Express
# 292           Machesney Park    AK    99514           MasterCard
# 293              Barneshaven    AK    99680     American Express
# 294  Lake Christopherchester    AK    99501           MasterCard
#
#       Credit Card Number  CVV
# 0    4275 6917 9930 9840  788
# 1    4740 6467 0961 7374  949
# 2    5219 2280 7176 2887  870
# 3    4961 4535 7541 0535  671
# 4    4445 6003 9684 2439  864
# ..                   ...  ...
# 290  4681 8515 4150 6980  163
# 291    3752 769014 97118  861
# 292    3783 392789 62879  254
# 293  4766 9875 0343 7075  759
# 294    3787 569703 14481  344
#
# [295 rows x 14 columns]
