# %%
from makefake_companies import FakeCompany, FakeAthleticClub, fake, phony

# %%
fake.iana_id()[:5]
# Out:
# '54619'

# %%
FakeCompany()
# Out:
# Name: Mcbride-Mcgee
# Category: Limited Liability Company
# Number of Employees: 449
# City:  Thompsonborough
# State: WV
# Zip Code: 25291
# Departments: ['Management', 'Accounting', 'Sales', 'Marketing', 'Security', 'IT']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
company = FakeCompany()

# %%
company
# Out:
# Name: Mcbride-Mcgee
# Category: Limited Liability Company
# Number of Employees: 449
# City:  Thompsonborough
# State: WV
# Zip Code: 25814
# Departments: ['Management', 'Accounting', 'Sales', 'Marketing', 'Security', 'IT']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
FakeAthleticClub()
# Out:
# Name: Sum Atmosphere Fitness
# Category: Athletic Club
# Number of Employees: 11
# City:  Joyceborough
# State: MS
# Zip Code: 39480
# Departments: ['Management', 'Personal Training', 'Coaching Staff', 'Sales and Merchandise', 'Diet and Nutrition', 'Marketing', 'Maintenance']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
SMRC = FakeAthleticClub(name="SMRC", state='CA', city='San Diego', employee_size=25)

# %%
SMRC.Departments
# Out:
# ['Management',
#  'Personal Training',
#  'Coaching Staff',
#  'Sales and Merchandise',
#  'Diet and Nutrition',
#  'Marketing',
#  'Maintenance']

# %%
type(True)
# Out:
# bool

# %%
SMRC
# Out:
# Name: SMRC
# Category: Athletic Club
# Number of Employees: 25
# City:  San Diego
# State: CA
# Zip Code: 94781
# Departments: ['Management', 'Personal Training', 'Coaching Staff', 'Sales and Merchandise', 'Diet and Nutrition', 'Marketing', 'Maintenance']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
SMRC_Members= SMRC.MakeFakeMembers()

# %%
SMRC_Employees= SMRC.MakeFakePayroll()

# %%
import pandas as pd

# %%
pd.DataFrame(
    SMRC_Members
)
# Out:
#     First Name Last Name    Phone Number                          Address  \
# 0      Natalie   Flowers  1-799-847-1715                377 Ross Causeway
# 1       Joshua      Long  1-493-284-6141               261 Alexander Pike
# 2      Zachary      Ross    820-021-8401        6384 Turner Dam Suite 628
# 3        Peter  Crawford  (625) 108-4095  28823 Patterson Vista Suite 590
# 4      Cynthia  Hamilton    769-173-1093             87584 Gonzales Crest
# ..         ...       ...             ...                              ...
# 217       Paul  Anderson    967.452.2021          797 Barry Flat Apt. 803
# 218      Jason     White  (696) 967-9924       51311 Kyle Forge Suite 318
# 219     Andrew  Stephens  (790) 883-9969            3378 Katherine Tunnel
# 220    William     Silva  1-559-688-3296                681 Anna Crescent
# 221      Shawn     White    437-407-4671       806 Johnson Manor Apt. 010
#
#               City State Zip Code Member ID Membership Date Membership Plan
# 0        San Diego    CA    90756      2823      05/15/2016          Silver
# 1        San Diego    CA    93864      8174      04/26/2022        Platinum
# 2        San Diego    CA    90372      7035      10/22/2011            Gold
# 3        San Diego    CA    91432      5932      02/13/2002          Silver
# 4        San Diego    CA    94776      1314      02/19/2022        Platinum
# ..             ...   ...      ...       ...             ...             ...
# 217      New James    CA    90756      6388      12/13/2022          Silver
# 218   North Sandra    CA    92321      4231      05/08/2009          Silver
# 219         Irvine    CA    90756      1943      04/04/2015        Platinum
# 220  Alexandraside    CA    91834      5726      06/18/2006          Silver
# 221      Greenfort    CA    90756      3985      10/10/2009            Gold
#
# [222 rows x 10 columns]

# %%
pd.DataFrame(
    SMRC_Employees
)
# Out:
#    Employee ID First Name   Last Name Date Of Birth       Phone Number  \
# 0        26021    Tiffany        Rios    07/11/1987       840-726-1799
# 1        38775     Shelby       Grant    06/22/1995       727-757-5250
# 2        78547     Brandi       Jones    08/14/1993       903.105.1607
# 3        27053      Erica        Ruiz    12/21/1987       936.941.0173
# 4        39437      Jacob      Mullen    04/27/1991       599.393.9843
# 5        52525       Ryan       Allen    11/29/1994     (785) 395-8572
# 6        77321   Samantha      Thomas    10/25/1998     1-638-647-9680
# 7        65193     Amanda   Robertson    09/13/1988     1-911-545-5677
# 8        84232      Amber     Johnson    04/05/1989       655-664-5327
# 9        67423      Paula    Williams    09/04/1994     1-339-736-4343
# 10       18637      Diana     Shaffer    08/01/1986     1-232-465-6552
# 11       26250   Cheyenne        King    09/07/2000  +1-(082)-063-0329
# 12       63069     Kristi     Stevens    11/10/1989     1-821-708-6400
# 13       29640      Alexa  Livingston    03/11/1991     1-392-483-6682
# 14       55258   Clifford     Pearson    04/27/1992     (641) 991-8375
# 15       54195      Ethan      Larson    10/18/1989     1-696-902-3386
# 16       66990   Victoria       Adams    05/23/1998     1-628-216-5850
# 17       83890  Alexander          Wu    04/14/1998  +1-(579)-167-7554
# 18       58103      James       Hogan    07/04/1988     1-751-006-5160
# 19       30897     Steven       Parks    08/21/1997       914-976-7798
# 20       81255       Lori      Bowman    04/09/1992     (648) 884-5389
# 21       88448     Daniel    Martinez    02/13/1985  +1-(490)-127-3933
# 22       16373    Belinda        Gray    03/05/1985     1-522-529-5148
# 23       70627    Michael   Rodriguez    04/06/1994       392.503.1588
