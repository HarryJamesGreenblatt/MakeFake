# %%
from make_fake_companies import Company

# %%
company = Company()

# %%
import pandas as pd

pd.DataFrame(
    company.MakeFakePayroll()
)
# Out:
#     Employee ID First Name   Last Name Date Of Birth       Phone Number  \
# 0       4763951     Daniel    Chambers    09/27/1983     1-786-468-4333
# 1       1016072       Chad    Odonnell    07/21/1960     (215) 316-1762
# 2       3533606     Robert     Huffman    10/30/1992     (583) 729-3649
# 3       8596733      David     Johnson    08/08/1965  +1-(992)-512-7720
# 4        444055      Sarah     Douglas    03/21/1967     (141) 480-7079
# ..          ...        ...         ...           ...                ...
# 221     4985489       Alan   Fernandez    09/11/1964     (262) 598-7593
# 222     6380244       Jill  Richardson    09/22/1968       265-601-0065
# 223     2251709       Mark     Farrell    12/16/1985       267-767-1777
# 224      171300   Victoria       Jones    04/28/1980     1-329-730-2590
# 225     5553436    Colleen       Nolan    07/28/1988       410.034.4251
#
#                            Address               City State Zip Code  \
# ...
