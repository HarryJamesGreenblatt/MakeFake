# %%
from make_fake_companies import FakeCompany, FakeAthleticClub, fake, phony

# %%
fake.iana_id()[:5]
# Out:
# '95091'

# %%
FakeCompany()
# Out:
# Name: Davis, Williams and Evans
# Category: Limited Partnership
# Number of Employees: 395
# City:  East Maxhaven
# State: CT
# Zip Code: 06291
# Departments: ['Management', 'Accounting', 'Sales', 'Marketing', 'Security', 'IT']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
company = FakeCompany()

# %%
company
# Out:
# Name: Davis, Williams and Evans
# Category: Limited Partnership
# Number of Employees: 395
# City:  East Maxhaven
# State: CT
# Zip Code: 06256
# Departments: ['Management', 'Accounting', 'Sales', 'Marketing', 'Security', 'IT']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
FakeAthleticClub()
# Out:
# Name: Injuries Associations Fitness
# Category: Athletic Club
# Number of Employees: 118
# City:  West Douglas
# State: DE
# Zip Code: 19848
# Departments: ['Management', 'Personal Training', 'Coaching Staff', 'Sales and Merchandise', 'Diet and Nutrition', 'Marketing', 'Maintenance']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
SMRC = FakeAthleticClub(name="SMRC", state='CA', city='San Diego', employee_size=25)

# %%
SMRC.Departments
# Out:
# ['Management',
#  'Personal Training',
#  'Coaching Staff',
#  'Sales and Merchandise',
#  'Diet and Nutrition',
#  'Marketing',
#  'Maintenance']

# %%
type(True)
# Out:
# bool

# %%
SMRC
# Out:
# Name: SMRC
# Category: Athletic Club
# Number of Employees: 25
# City:  San Diego
# State: CA
# Zip Code: 95708
# Departments: ['Management', 'Personal Training', 'Coaching Staff', 'Sales and Merchandise', 'Diet and Nutrition', 'Marketing', 'Maintenance']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
SMRC_Members= SMRC.MakeFakeMembers()

# %%
SMRC_Employees= SMRC.MakeFakePayroll()

# %%
import pandas as pd

# %%
pd.DataFrame(
    SMRC_Members
)
# Out:
#    First Name Last Name       Phone Number                          Address  \
# 0        Mark    Bailey  +1-(561)-311-9359     27641 Catherine Key Apt. 514
# 1      Victor    Taylor       826.521.5739                88232 Heidi Inlet
# 2       Robin      Reed     1-461-091-8407       873 Porter Bridge Apt. 973
# 3     Vincent      Neal     1-340-761-5822                  64570 Lee Manor
# 4        John    Moreno     1-765-930-9941                8004 Deborah Burg
# 5     Sabrina  Mccarthy     (137) 798-2309                 6450 Jones Roads
# 6        Sean     Young       595-975-2091                101 Burch Village
# 7    Kimberly     Blair     1-787-631-4559                66737 Tyler Spurs
# 8    Adrienne      King     (764) 177-1546              547 Kennedy Meadows
# 9    Kathleen      Pena       628.709.9792     77919 Ronald Plains Apt. 984
# 10      Jason     Smith       109.083.7857          8314 Donna Row Apt. 444
# ...

# %%
pd.DataFrame(
    SMRC_Employees
)
# Out:
#    Employee ID First Name  Last Name Date Of Birth    Phone Number  \
# 0        56136   Michelle   Williams    01/28/1996  1-542-815-1349
# 1        35845       Gary     Austin    03/20/1994  (953) 830-3939
# 2        64472      Aaron   Hamilton    03/10/1997    307-750-7085
# 3        36642      Julie    Hoffman    07/19/1991  1-918-972-3916
# 4        12567    Katelyn   Mitchell    04/13/1995    101-041-8890
# 5        44138     Daniel  Rodriguez    06/15/1989    523-127-8325
# 6        54484    Richard   Martinez    02/16/1986    087-803-1530
# 7        41262      Blake       Cole    11/27/1997    487.330.6880
# 8        49005     Daniel       Case    03/03/1993  (579) 398-0139
# 9        11837      Edwin      Scott    01/09/1985    154-247-5507
# 10       47077        Joy    Johnson    10/30/1999  1-880-837-7959
# 11       38775    Kaitlyn    Jenkins    02/08/1996  1-568-257-0596
# 12       31178    Kathryn      Flynn    07/31/2000  (304) 138-8175
# ...
