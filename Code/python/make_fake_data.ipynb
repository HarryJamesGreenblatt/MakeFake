# %%
from make_fake_companies import Company

# %%
Company()
# Out:
# Name: Hill-Holmes
# Category: Limited Liability Partnership
# Number of Employees: 61
# City:  West Christopherland
# State: MO
# Zip Code: 67911
# Departments: ['Management', 'Accounting', 'Sales', 'Marketing', 'Security', 'IT']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
company = Company()

# %%
company
# Out:
# Name: Hill-Holmes
# Category: Limited Liability Partnership
# Number of Employees: 61
# City:  West Christopherland
# State: MO
# Zip Code: 67911
# Departments: ['Management', 'Accounting', 'Sales', 'Marketing', 'Security', 'IT']
# Payroll: dict_keys(['Employee ID', 'First Name', 'Last Name', 'Date Of Birth', 'Phone Number', 'Address', 'City', 'State', 'Zip Code', 'Hire Date', 'Salary', 'Department'])

# %%
import pandas as pd

pd.DataFrame(
    company.MakeFakePayroll()
)
# Out:
#    Employee ID First Name  Last Name Date Of Birth       Phone Number  \
# 0      2785204      David      Ramos    02/21/1974     (040) 816-8831
# 1      1261156    Beverly        Ray    02/02/1992       469-880-8994
# 2       729896    Crystal      Moore    01/25/1995  +1-(479)-775-9806
# 3      5074153     Sherry      Woods    09/15/1982       766-485-0525
# 4      1374935      Larry   Gallegos    06/14/1985       099.705.2649
# ..         ...        ...        ...           ...                ...
# 56     3814930     Amanda     Watson    03/25/1993     (442) 412-2964
# 57     5896870      Jason      Beard    03/12/1974       687.540.9140
# 58     6048841     Robert  Carpenter    02/14/1986     (197) 261-3585
# 59     6715756      Kevin     Orozco    04/27/1977       445.852.3231
# 60     4941055    Brandon    Johnson    11/13/1985     1-092-202-0221
#
#                           Address                  City State Zip Code  \
# ...
